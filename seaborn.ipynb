# %%
import seaborn as sns
import numpy as np

# %% [markdown]
# Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %% [markdown]
# Ans:
# 1. scatter plot: this plot represents the points on the graph. using this plot we can check area where desity of plotted dots.
# 2. hist plot: This plot represents the histogram graphg. this graph we uses when to check the count of occurances of any specific column values.
# 3. pair plot: This graph gives multiple plots overs the numeric data columns presents into given data sets.
# 4. cat plot: This is categorical plot. x-axis data will be shows in unique values of given column.
# 5. joint plot: This plot provides scatter and histogram graph in single figure.
# 6. box plot: This is categorical plot.

# %% [markdown]
# Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
# "timepoint" and y = "signal" for different events and regions.

# %%
fmri=sns.load_dataset("fmri")
print(fmri)
sns.lineplot(data=fmri,x=fmri.timepoint,y=fmri.signal,hue='event', style="region")
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
# 'pclass', y = 'age' and y = 'fare'.

# %%
import matplotlib.pyplot as plt
titanic=sns.load_dataset("titanic")
#print(titanic)
fig,ax=plt.subplots(1,2,sharex=True,figsize=(10,5))
sns.boxplot(data=titanic,x=titanic.pclass,y=titanic.age,ax=ax[0])
sns.boxplot(data=titanic,x=titanic.pclass,y=titanic.fare,ax=ax[1])
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %% [markdown]
# Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
# parameter for the 'cut' column of the diamonds dataset.

# %%
diamonds=sns.load_dataset("diamonds")
print(diamonds)
sns.histplot(data=diamonds,col="price",hue='cut')
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]
# ...

# %% [markdown]
# Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
# of the iris dataset.

# %%
iris=sns.load_dataset("iris")
#print(iris)
sns.pairplot(data=iris,hue='species')

# %% [markdown]
# Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
flights=sns.load_dataset("flights")
flights = flights.pivot("month", "year", "passengers")
print(flights)
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights,annot=True, fmt="d", linewidths=.5, ax=ax)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 5
#       3 print(flights)
#       4 f, ax = plt.subplots(figsize=(9, 6))
# ----> 5 sns.heatmap(flights,annot=True, fmt="d", linewidths=.5, ax=ax)
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
# ...
